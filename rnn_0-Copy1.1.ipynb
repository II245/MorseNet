# %%
import librosa
import librosa.display
import scipy.io.wavfile
import sklearn
import tensorflow as tf
import numpy as np
from config import SEQ_LENGTH, FRAMERATE, CHUNK, FFT_SIZE
import matplotlib.pyplot as plt
import generate_wav_samples as gen
import os
import keras
import itertools
from config import MORSE_CHR
from tqdm import tqdm

from keras import backend as K
from keras.layers.convolutional import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D
from keras.layers import Input, Dense, Activation,TimeDistributed
from keras.layers import Reshape, Lambda
from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.layers.recurrent import GRU, SimpleRNN,LSTM
from keras.optimizers import SGD, Adam
from keras.utils.data_utils import get_file
from keras.preprocessing import image
import keras.callbacks
# Out:
# Using TensorFlow backend.

# %%
OUTPUT_DIR = 'rnn_output'

# %%
class VizCallback(keras.callbacks.Callback):
    def __init__(self, run_name, test_func, X):
        self.test_func = test_func
        self.output_dir = os.path.join(
            OUTPUT_DIR, run_name)
        self.X = X

    def show_edit_distance(self, num):
        print('edit distance: ', num)
        """
        num_left = num
        mean_norm_ed = 0.0
        mean_ed = 0.0
        while num_left > 0:
            word_batch = next(self.text_img_gen)[0]
            num_proc = min(word_batch['the_input'].shape[0], num_left)
            decoded_res = decode_batch(self.test_func,
                                       word_batch['the_input'][0:num_proc])
            for j in range(num_proc):
                edit_dist = editdistance.eval(decoded_res[j],
                                              word_batch['source_str'][j])
                mean_ed += float(edit_dist)
                mean_norm_ed += float(edit_dist) / len(word_batch['source_str'][j])
            num_left -= num_proc
        mean_norm_ed = mean_norm_ed / num
        mean_ed = mean_ed / num
        print('\nOut of %d samples:  Mean edit distance:'
              '%.3f Mean normalized edit distance: %0.3f'
              % (num, mean_ed, mean_norm_ed))
        """

    def on_epoch_end(self, epoch, logs={}):
        self.model.save_weights(os.path.join(self.output_dir, 'weights%02d.h5' % (epoch)))
        
        self.show_edit_distance(256)
                
        for i in range(5):
            labels = self.X[1][i:i+1]
            print('labels: ', labels_to_text([int(e) for e in labels[0]]))
        
        word_batch = self.X[0][:5]
        res = decode_batch(self.test_func, word_batch)
        print('result lens: ', len(res))
        for e in res[:5]:
            print(e)
            

def labels_to_text(i):
    return [MORSE_CHR[e] for e in i]

def decode_batch2(test_func, word_batch):
    out = test_func([word_batch])[0]
    ret = []
    print(np.argmax(out, axis = -1))
    return np.argmax(out, axis = -1)


def decode_batch(test_func, word_batch):
    out = test_func([word_batch])[0]
    r = np.argmax(out, axis=-1)
    #print('r: ', r)
    
    
    res = []
    for a in r:
        sub_res = []
        for i, e in enumerate(a):
            #print(i, e)
            if i == 0:
                sub_res.append(e)
                continue
            if (e == a[i-1]):
                continue
            if (e == len(MORSE_CHR) - 1):
                continue
            sub_res.append(e)
            
        sub_res = [e for e in sub_res if e != len(MORSE_CHR) - 1]
        res.append(sub_res)
            
    #[e if (i==0 or c != bc[i-1] and c!=3)]
    #print('res: ', res)
    return res

# %%
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    # the 2 is critical here since the first couple outputs of the RNN
    # tend to be garbage:
    #y_pred = y_pred[:, 2:, :]
    bc = K.ctc_batch_cost(labels, y_pred, input_length, label_length)
    return bc

# %%
sample_len = SEQ_LENGTH

#SEQ_LENGTH = 24000

samples_count = 500
sample_len = 80000
sr = 8000
dict_len = len(MORSE_CHR)
max_seq_len = 1
mel_count = 1
mel_len = 160

# %%
g = gen.seq_generator(SEQ_LENGTH, FRAMERATE, 1)

# %%
def read_data(set_len):
    l = np.zeros([samples_count, max_seq_len], dtype=np.int32)
    #l += -1.0
    X = np.zeros([samples_count,  mel_len, mel_count])
    input_length = np.zeros([samples_count, 1], dtype=np.int32)
    label_length = np.zeros([samples_count, 1], dtype=np.int32)

    i = 0
    for wave, label_indexes, labels, c in tqdm(g):
        wave = wave.reshape(SEQ_LENGTH)
        wave = librosa.util.normalize(wave)
        mel = librosa.feature.melspectrogram(wave, sr=sr, n_fft=500, n_mels=mel_count,hop_length=250)
        
        #print('mel shape', mel.shape)
        #mel = mel.reshape(mel_len, mel_count)
        mel = mel.T
        #print('mel shape reshaped', mel.shape)
        
        
        mel = mel / np.max(mel)
        #mel = np.round(mel, decimals=4)

        X[i, :, :] = mel
        #
        labels = [l for l in labels if l != ' ']
        #print(labels)
        l[i, :len(labels)] = labels
        input_length[i, :] = mel.shape[0]
    
        
        label_length[i, :1] = c
        
            
        #print(label_length)
        #print(l)
        
        #raise Exception
        
        #print(labels)
        #break
        
        i+=1
        if i == set_len:
            break
        
    return [X, l, input_length, label_length], l

# %%
X, l = read_data(samples_count)
# Out:
# 497it [00:05, 106.80it/s]

# %%
X_val, l_val = read_data(10)
# Out:
# 0it [00:00, ?it/s]

# %%
dict_len
# Out:
# 4

# %%
conv_filters = 32
kernel_size = 30
pool_size = 30
time_dense_size = 32
rnn_size = 512
minibatch_size = 32

# %%
ctc_lambda_func
# Out:
# <function __main__.ctc_lambda_func(args)>

# %%
input_shape = (mel_len, mel_count)

act = 'relu'
input_data = Input(name='the_input', shape=input_shape, dtype='float32')

inner = Conv1D(conv_filters, kernel_size, padding='same', 
               activation=act, kernel_initializer='he_normal',
               name='conv1')(input_data)

mp = MaxPooling1D(pool_size=pool_size, name='max1', strides=1, padding='same')(inner)
gru = GRU(128, return_sequences=True, kernel_initializer='he_normal', name='gru1')(mp)
#srnn = SimpleRNN(100, return_sequences=True)(mp)
#lstm = LSTM(50, return_sequences=True)(mp)

dense2 = Dense(128, kernel_initializer='he_normal', name='dense2')(gru)
dense1 = Dense(dict_len, kernel_initializer='he_normal', name='dense1')(dense2)

y_pred = Activation('softmax', name='softmax')(dense1)

Model(inputs=input_data, outputs=y_pred).summary()

labels = Input(name='the_labels', shape=[max_seq_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')

print(y_pred, labels, input_length, label_length)

loss_out = Lambda(
    ctc_lambda_func, output_shape=(1,),
    name='ctc')([y_pred, labels, input_length, label_length])

# clipnorm seems to speeds up convergence
model = Model(inputs=[input_data, labels, input_length, label_length], outputs=loss_out)

# the loss calc occurs elsewhere, so use a dummy lambda func for the loss
sgd = SGD(lr=0.05, decay=1e-6, momentum=0.9, nesterov=True, clipnorm=5) #
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=sgd)

test_func = K.function([input_data], [y_pred])
viz_cb = VizCallback('test', test_func, X_val)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, 160, 1)            0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 160, 32)           992
# _________________________________________________________________
# max1 (MaxPooling1D)          (None, 160, 32)           0
# _________________________________________________________________
# gru1 (GRU)                   (None, 160, 128)          61824
# _________________________________________________________________
# dense2 (Dense)               (None, 160, 128)          16512
# _________________________________________________________________
# dense1 (Dense)               (None, 160, 4)            516
# _________________________________________________________________
# softmax (Activation)         (None, 160, 4)            0
# =================================================================
# Total params: 79,844
# Trainable params: 79,844
# Non-trainable params: 0
# _________________________________________________________________
# Tensor("softmax/truediv:0", shape=(?, 160, 4), dtype=float32) Tensor("the_labels:0", shape=(?, 1), dtype=float32) Tensor("input_length:0", shape=(?, 1), dtype=int64) Tensor("label_length:0", shape=(?, 1), dtype=int64)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4249: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4229: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.fit(X, l, validation_split=0.1, batch_size=100, callbacks=[viz_cb], epochs=30)
# Out:
# Train on 450 samples, validate on 50 samples
# Epoch 1/30
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2285 - val_loss: 1.5735
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 2/30
# 450/450 [==============================] - 1s 3ms/step - loss: 1.0015 - val_loss: 0.5533
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 3/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6842 - val_loss: 0.4425
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 4/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6238 - val_loss: 0.5958
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 5/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.5635 - val_loss: 0.3884
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 6/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6217 - val_loss: 0.5708
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 7/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.8972 - val_loss: 0.3414
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 8/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.4084 - val_loss: 0.3694
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 9/30
# 450/450 [==============================] - 2s 3ms/step - loss: 0.3513 - val_loss: 0.2531
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 10/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.2710 - val_loss: 0.2816
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 11/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.2053 - val_loss: 0.1463
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 12/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1678 - val_loss: 0.0892
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 13/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1372 - val_loss: 0.0802
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 14/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1160 - val_loss: 0.0772
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 15/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0936 - val_loss: 0.0944
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 16/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0925 - val_loss: 0.0613
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 17/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0829 - val_loss: 0.0419
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 18/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0524 - val_loss: 0.0701
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 19/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0650 - val_loss: 0.0794
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 20/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.2218 - val_loss: 0.0998
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 21/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1422 - val_loss: 0.0523
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 22/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0986 - val_loss: 0.0472
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 23/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0517 - val_loss: 0.0674
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 24/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.2451 - val_loss: 0.0371
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 25/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0635 - val_loss: 0.0524
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 26/30
# 450/450 [==============================] - 1s 3ms/step - loss: 2.5324 - val_loss: 0.6782
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# []
# [2]
# [1]
# [1]
# [1]
# Epoch 27/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.4251 - val_loss: 0.2109
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 28/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1450 - val_loss: 0.0725
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 29/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0698 - val_loss: 0.0319
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]
# Epoch 30/30
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0614 - val_loss: 0.0321
# edit distance:  256
# labels:  ['E']
# labels:  ['E']
# labels:  ['T']
# labels:  ['T']
# labels:  ['T']
# result lens:  5
# [2]
# [2]
# [1]
# [1]
# [1]

# %%
[e for e in l_val]
# Out:
# [array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([0.])]

# %%
l_val.shape
# Out:
# (500, 4)

# %%
model.predict(X)
# Out:
# array([[2.13336106e-02],
#        [1.08400241e-01],
#        [5.21433423e-04],
#        [2.25297838e-01],
#        [4.52917116e-03],
#        [5.61966598e-02],
#        [1.50743211e-02],
#        [7.63259188e-04],
#        [2.96722483e-02],
#        [9.35048796e-03],
#        [2.12552190e-01],
#        [5.84906265e-02],
#        [1.68770418e-01],
#        [4.40781121e-04],
#        [2.90427660e-03],
#        [6.16485253e-02],
#        [7.10845413e-03],
#        [3.29322636e-01],
#        [2.22740066e-03],
#        [1.12101818e-02],
#        [5.43251447e-03],
#        [6.61901839e-04],
#        [2.12766286e-02],
#        [8.63374025e-03],
#        [7.39439130e-02],
#        [3.65500781e-03],
#        [1.80977362e-03],
#        [1.69335399e-02],
#        [7.35613257e-02],
#        [1.91027846e-03],
#        [1.27884047e-03],
#        [9.45606176e-03],
#        [5.68844238e-03],
#        [4.01843805e-04],
#        [1.63126108e-03],
#        [4.96169040e-03],
#        [5.26374578e-03],
#        [6.54203072e-02],
#        [1.36923045e-02],
#        [6.43967302e-04],
#        [4.52572014e-04],
#        [5.25239743e-02],
#        [3.96052492e-04],
#        [1.19807646e-02],
#        [6.87290058e-02],
#        [3.64389876e-03],
#        [1.35783732e-01],
#        [1.69153422e-01],
#        [1.84410473e-03],
#        [7.53141101e-03],
#        [7.12993070e-02],
#        [7.24278972e-04],
#        [2.81930971e-03],
#        [2.62130774e-03],
#        [3.07921082e-01],
#        [2.36474350e-02],
#        [5.91315469e-03],
#        [5.20308688e-02],
#        [6.10870868e-02],
#        [2.12799571e-03],
#        [6.58234907e-03],
#        [2.45168176e-03],
#        [6.25101477e-03],
#        [2.90153571e-03],
#        [2.80139931e-02],
#        [3.59873623e-02],
#        [7.86389969e-03],
#        [2.22751545e-03],
#        [5.13169216e-03],
#        [6.10567909e-03],
#        [1.12483511e-02],
#        [2.90816999e-03],
#        [7.16214348e-03],
#        [4.92807716e-01],
#        [2.61481106e-03],
#        [9.30052903e-03],
#        [1.91445893e-03],
#        [1.35585549e-03],
#        [8.70655058e-04],
#        [3.08991186e-02],
#        [5.91765977e-02],
#        [6.56001153e-04],
#        [2.78023835e-02],
#        [2.82842815e-02],
#        [9.09738690e-02],
#        [6.05869710e-01],
#        [1.13261482e-02],
#        [4.91543114e-03],
#        [1.64825860e-02],
#        [1.16713447e-02],
#        [1.68805907e-03],
#        [3.52033675e-02],
#        [1.13998628e+00],
#        [1.03196478e-03],
#        [1.01328172e-01],
#        [4.85341018e-03],
#        [2.50613759e-03],
#        [2.43432522e-02],
#        [2.22453196e-02],
#        [9.46701225e-03],
#        [3.80324088e-02],
#        [2.67625023e-02],
#        [2.70559220e-03],
#        [1.59813324e-03],
#        [3.59539129e-02],
#        [5.29331993e-03],
#        [4.22543380e-04],
#        [3.07841897e-02],
#        [1.91782811e-03],
#        [3.49408016e-03],
#        [5.01065254e-01],
#        [3.01504046e-01],
#        [1.57880206e-02],
#        [3.15869693e-03],
#        [5.31123311e-04],
#        [2.24174261e-02],
#        [1.76212773e-01],
#        [2.31588399e-03],
#        [6.91415509e-04],
#        [2.12071463e-02],
#        [3.63794854e-03],
#        [6.56791311e-03],
#        [2.44542826e-02],
#        [1.56005081e-02],
#        [1.15816551e-03],
#        [1.08272792e-03],
#        [9.57894232e-03],
#        [1.46004006e-01],
#        [2.08743080e-03],
#        [2.57892814e-03],
#        [1.29049004e-03],
#        [9.68343695e-04],
#        [2.04528333e-03],
#        [6.39080703e-02],
#        [5.12247741e-01],
#        [9.44619533e-03],
#        [1.74517231e-03],
#        [6.92264317e-03],
#        [3.33838584e-03],
#        [7.93833844e-03],
#        [1.55199016e-03],
#        [4.80158255e-03],
#        [6.82918280e-02],
#        [1.13015445e-02],
#        [1.55109551e-03],
#        [1.05234122e+00],
#        [2.78914422e-01],
#        [1.93587679e-03],
#        [1.05606131e-02],
#        [2.10772408e-03],
#        [8.01524206e-04],
#        [2.20882315e-02],
#        [2.04330124e-03],
#        [1.68758444e-03],
#        [3.02859753e-01],
#        [1.27809937e-03],
#        [1.85437407e-03],
#        [3.44218779e-03],
#        [2.01491967e-01],
#        [1.03995577e-02],
#        [2.94771953e-03],
#        [8.70667040e-01],
#        [6.25249445e-02],
#        [7.49440584e-03],
#        [7.66536780e-03],
#        [2.91678379e-03],
#        [8.43151822e-04],
#        [3.50875873e-03],
#        [1.72593759e-03],
#        [9.98525182e-04],
#        [9.21162870e-03],
#        [4.73226666e-01],
#        [1.03428192e-03],
#        [3.62511009e-01],
#        [9.91075882e-04],
#        [2.67034192e-02],
#        [1.55404024e-03],
#        [1.18765444e-03],
#        [2.28247359e-01],
#        [1.46753192e-02],
#        [7.09732936e-04],
#        [7.48695433e-02],
#        [7.57630100e-04],
#        [6.84116618e-04],
#        [5.55356979e-01],
#        [3.10965836e-01],
#        [6.44837618e-02],
#        [5.96160814e-02],
#        [1.86808445e-02],
#        [6.04919763e-03],
#        [2.99754692e-03],
#        [1.30928622e-03],
#        [1.35351764e-03],
#        [3.34009016e-03],
#        [1.65234700e-01],
#        [1.01327256e-03],
#        [8.47675465e-03],
#        [6.40149089e-03],
#        [4.38508123e-01],
#        [8.73101642e-04],
#        [9.48955072e-04],
#        [1.10447584e-02],
#        [1.81419492e-01],
#        [7.56019279e-02],
#        [6.17659301e-04],
#        [5.19983424e-03],
#        [7.99886107e-01],
#        [3.08003655e-04],
#        [1.57050183e-03],
#        [7.74789415e-03],
#        [2.99384892e-02],
#        [6.83072880e-02],
#        [5.86918439e-04],
#        [9.53213312e-03],
#        [2.35897247e-02],
#        [1.45169841e-02],
#        [1.60006946e-03],
#        [1.24485148e-02],
#        [6.66812644e-04],
#        [5.19887656e-02],
#        [1.00994438e-01],
#        [7.19952490e-03],
#        [9.37073142e-04],
#        [9.21024680e-02],
#        [3.46651450e-02],
#        [1.08654203e-03],
#        [1.46533931e-02],
#        [8.09356454e-04],
#        [7.22668692e-03],
#        [3.28351604e-03],
#        [1.30852312e-02],
#        [5.35555137e-03],
#        [2.03516334e-03],
#        [1.09922066e-01],
#        [2.77952198e-03],
#        [2.27312511e-03],
#        [5.10954373e-02],
#        [7.09791388e-03],
#        [1.09005868e-02],
#        [2.98993010e-03],
#        [4.23378438e-01],
#        [2.21073092e-03],
#        [6.51357919e-02],
#        [7.57510215e-02],
#        [3.20912409e-03],
#        [9.69747454e-03],
#        [4.63671703e-03],
#        [8.26270878e-03],
#        [1.72600932e-02],
#        [1.40596294e+00],
#        [2.95390725e-01],
#        [3.37537974e-02],
#        [1.33015984e-03],
#        [2.71767448e-03],
#        [1.61952991e-03],
#        [2.15930063e-02],
#        [4.78059752e-03],
#        [1.00681150e+00],
#        [4.13672537e-01],
#        [3.33505310e-02],
#        [4.26382432e-03],
#        [1.75196558e-01],
#        [5.38027938e-03],
#        [1.03746669e-03],
#        [4.58271243e-03],
#        [7.13254325e-03],
#        [6.69422895e-02],
#        [7.97135290e-04],
#        [1.45113945e-03],
#        [2.22354871e-03],
#        [2.10764748e-03],
#        [2.36286767e-04],
#        [2.39564888e-02],
#        [8.06294024e-01],
#        [1.09893735e-02],
#        [8.96401703e-03],
#        [2.30273362e-02],
#        [9.11867770e-04],
#        [4.34198320e-01],
#        [4.18685898e-02],
#        [1.41760625e-03],
#        [7.12691748e-04],
#        [1.55250833e-03],
#        [7.85123731e-04],
#        [2.31617992e-03],
#        [9.31152143e-03],
#        [1.35365911e-02],
#        [4.49622214e-01],
#        [1.53835714e-01],
#        [7.05226213e-02],
#        [1.06746308e-03],
#        [1.52534069e-02],
#        [2.84654886e-01],
#        [2.24302988e-03],
#        [6.21661195e-04],
#        [1.61288418e-02],
#        [1.67350543e+00],
#        [1.90689473e-03],
#        [7.35798776e-02],
#        [6.95596565e-04],
#        [1.45295858e-02],
#        [4.37278450e-01],
#        [8.06946657e-04],
#        [3.03524733e-03],
#        [1.69887091e-03],
#        [4.26549790e-03],
#        [1.89740420e-03],
#        [9.21006575e-02],
#        [2.06546136e-03],
#        [8.73104855e-03],
#        [3.15647051e-02],
#        [1.22151256e-03],
#        [2.63726572e-03],
#        [3.16107906e-02],
#        [3.11961328e-03],
#        [7.92503282e-02],
#        [5.43495524e-04],
#        [7.72916304e-04],
#        [5.05448738e-03],
#        [6.07292764e-02],
#        [7.68414093e-03],
#        [8.25878084e-01],
#        [9.31181770e-04],
#        [1.82847562e-03],
#        [4.52561071e-03],
#        [4.97262180e-02],
#        [5.15413821e-01],
#        [3.00482125e-03],
#        [5.51099656e-03],
#        [1.84263773e-02],
#        [2.05130540e-02],
#        [8.22594389e-03],
#        [7.88001716e-03],
#        [1.86672655e-03],
#        [1.75968767e-03],
#        [1.97058786e-02],
#        [1.04329884e+00],
#        [7.29063451e-02],
#        [1.22888458e+00],
#        [7.22079426e-02],
#        [1.32086836e-02],
#        [3.91840905e-01],
#        [1.33039674e-03],
#        [7.18796626e-04],
#        [6.92487927e-04],
#        [2.28889473e-02],
#        [1.45246098e-02],
#        [5.82035491e-03],
#        [6.20011650e-02],
#        [1.39130047e-03],
#        [3.71582992e-03],
#        [6.38550892e-03],
#        [2.36590669e-04],
#        [1.33570163e-02],
#        [1.68025922e-02],
#        [6.05730899e-03],
#        [1.66408777e-01],
#        [2.54507959e-02],
#        [3.08762401e-01],
#        [5.11495955e-02],
#        [2.00872775e-03],
#        [2.09924765e-02],
#        [1.10308397e+00],
#        [9.50425684e-01],
#        [2.15707743e-03],
#        [3.03352659e-04],
#        [2.05598269e-02],
#        [1.50651351e-01],
#        [1.01539946e+00],
#        [1.57613307e-02],
#        [6.69454813e-01],
#        [1.26045078e-01],
#        [1.57387508e-03],
#        [7.61117876e-01],
#        [2.43454403e-03],
#        [1.07948743e-02],
#        [8.01809132e-01],
#        [2.18937523e-03],
#        [1.65759083e-02],
#        [4.10893172e-01],
#        [5.28202057e-02],
#        [5.87728631e-04],
#        [9.33513939e-02],
#        [2.07080901e-01],
#        [9.59165336e-04],
#        [1.76268467e-03],
#        [9.36343241e-03],
#        [1.88305264e-03],
#        [3.06361504e-02],
#        [5.92533410e-01],
#        [8.51775520e-04],
#        [3.40303709e-03],
#        [6.55751079e-02],
#        [2.29920866e-03],
#        [2.22293986e-03],
#        [1.87146245e-03],
#        [3.90605517e-02],
#        [5.40336734e-03],
#        [3.37639451e-02],
#        [2.20079068e-03],
#        [3.40433937e-04],
#        [4.06427402e-03],
#        [3.00995111e-02],
#        [5.19619763e-01],
#        [1.56171799e+00],
#        [9.51370522e-02],
#        [2.77451612e-03],
#        [4.56173480e-01],
#        [3.00664781e-03],
#        [5.27526319e-01],
#        [5.36166783e-03],
#        [1.17729581e-03],
#        [4.22142856e-02],
#        [1.52475317e-03],
#        [8.28752294e-02],
#        [1.02539673e-01],
#        [4.11655102e-03],
#        [1.80924265e-03],
#        [7.19746854e-03],
#        [5.07257925e-03],
#        [3.85826873e-03],
#        [1.21757202e-03],
#        [1.39592588e-01],
#        [1.50959671e-03],
#        [4.77817506e-02],
#        [8.11967775e-02],
#        [3.35960113e-03],
#        [1.28820841e-03],
#        [9.51051340e-03],
#        [6.80488423e-02],
#        [1.29653424e-01],
#        [3.63415591e-02],
#        [1.96430506e-03],
#        [2.50706337e-02],
#        [9.87190986e-04],
#        [1.91777584e-03],
#        [2.47425307e-03],
#        [1.08415976e-01],
#        [1.57126077e-02],
#        [8.82124826e-02],
#        [7.12641049e-04],
#        [2.54299305e-03],
#        [1.01179280e-03],
#        [5.43989893e-03],
#        [3.99949774e-02],
#        [1.15148362e-03],
#        [4.58596507e-03],
#        [7.61884674e-02],
#        [3.11850518e-01],
#        [9.50710266e-04],
#        [5.34722582e-03],
#        [7.38739967e-02],
#        [5.38869901e-03],
#        [1.02254394e-02],
#        [2.88225412e-01],
#        [8.82656954e-04],
#        [1.21774944e-03],
#        [1.25215918e-01],
#        [1.24356779e-03],
#        [1.05266739e-03],
#        [5.15073817e-03],
#        [3.24340275e-04],
#        [5.37613919e-03],
#        [1.83924963e-03],
#        [1.10017629e-02],
#        [3.61433043e-03],
#        [2.28573047e-02],
#        [1.03180873e+00],
#        [1.13902462e-03],
#        [1.93972021e-01],
#        [1.24098838e-03],
#        [9.43710736e-04],
#        [7.51620308e-02],
#        [8.33694518e-01],
#        [1.17696158e-03],
#        [2.28405674e-03],
#        [9.97171272e-04],
#        [7.34710251e-04],
#        [5.32847364e-03],
#        [2.00975891e-02],
#        [7.86847249e-03],
#        [6.37805536e-02],
#        [3.93175304e-01],
#        [2.75730819e-01],
#        [6.91255380e-04],
#        [2.56134644e-02],
#        [2.48192713e-01],
#        [4.78582457e-02],
#        [7.38653615e-02],
#        [1.33424101e-03],
#        [5.10127284e-02],
#        [1.13366335e-03],
#        [2.87771113e-02],
#        [5.87106450e-03],
#        [4.60085832e-02],
#        [9.10103917e-02],
#        [4.61907219e-03],
#        [1.70793629e+00],
#        [1.25496881e-03],
#        [8.98849592e-03]], dtype=float32)
